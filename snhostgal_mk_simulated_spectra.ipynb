# %% [markdown]
# Part II :  (long version, generating simulated SEDs for all the galaxies)
#
# (1) Read in the master catalog generated in Part I
#
# (2) For each simulated SN host galaxy, use the EAZY code to make a simulated host galaxy spectrum (from the best-fitting photoz template)
#
# (3) Store each simulated spectrum as an ascii .dat file with wavelength in nm and AB mag (suitable input to the Subaru ETC).
#
# (4) Store the revised master catalog (now updated with SED .dat file names) as a simple ascii file "wfirst_snhostspec_master2.cat"

# %%
# %matplotlib inline

# %%
import numpy as np
from astropy.io import fits
from astropy.table import Table
from matplotlib import pyplot as plt
import snhostspec
from glob import glob

# %%
reload(snhostspec)
sim1 = snhostspec.SnanaSimData()
sim1.load_simdata_catalog('wfirst_snhostspec1.cat')
sim1.load_sed_data()
# Out:
# Initiliazed an empty WfirstSimData object
# Loading data for best-fit SEDs from 3DHST fits to observed photometry for all galaxies in all five CANDELS fields...

# %%
sim1.verbose=2
sim1.simulate_host_spectra(indexlist=[2,4], clobber=True)
# Out:
# Using Gabe Brammer's EAZY code to generate the best-fit SEDs of the observed galaxies that we have matched up to the SNANA simulation hostgal data.
# Skipping SED simulation for idx=0
# Skipping SED simulation for idx=1
# Generating 3DHST/sedsim.output/wfirst_simsed.000002.dat
# Skipping SED simulation for idx=3
# Generating 3DHST/sedsim.output/wfirst_simsed.000004.dat
# Skipping SED simulation for idx=5
# Skipping SED simulation for idx=6
# Skipping SED simulation for idx=7
# Skipping SED simulation for idx=8
# Skipping SED simulation for idx=9
# Skipping SED simulation for idx=10
# Skipping SED simulation for idx=11
# Skipping SED simulation for idx=12
# Skipping SED simulation for idx=13
# Skipping SED simulation for idx=14
# Skipping SED simulation for idx=15
# Skipping SED simulation for idx=16
# Skipping SED simulation for idx=17
# Skipping SED simulation for idx=18
# Skipping SED simulation for idx=19
# Skipping SED simulation for idx=20
# Skipping SED simulation for idx=21
# Skipping SED simulation for idx=22
# Skipping SED simulation for idx=23
# Skipping SED simulation for idx=24
# Skipping SED simulation for idx=25
# Skipping SED simulation for idx=26
# Skipping SED simulation for idx=27
# Skipping SED simulation for idx=28
# Skipping SED simulation for idx=29
# Skipping SED simulation for idx=30
# Skipping SED simulation for idx=31
# Skipping SED simulation for idx=32
# Skipping SED simulation for idx=33
# Skipping SED simulation for idx=34
# Skipping SED simulation for idx=35
# Skipping SED simulation for idx=36
# Skipping SED simulation for idx=37
# Skipping SED simulation for idx=38
# Skipping SED simulation for idx=39
# Skipping SED simulation for idx=40
# Skipping SED simulation for idx=41
# Skipping SED simulation for idx=42
# Skipping SED simulation for idx=43
# Skipping SED simulation for idx=44
# Skipping SED simulation for idx=45
# Skipping SED simulation for idx=46
# Skipping SED simulation for idx=47
# Skipping SED simulation for idx=48
# Skipping SED simulation for idx=49
# Skipping SED simulation for idx=50
# Skipping SED simulation for idx=51
# Skipping SED simulation for idx=52
# Skipping SED simulation for idx=53
# Skipping SED simulation for idx=54
# Skipping SED simulation for idx=55
# Skipping SED simulation for idx=56
# Skipping SED simulation for idx=57
# Skipping SED simulation for idx=58
# Skipping SED simulation for idx=59
# Skipping SED simulation for idx=60
# Skipping SED simulation for idx=61
# Skipping SED simulation for idx=62
# Skipping SED simulation for idx=63
# Skipping SED simulation for idx=64
# Skipping SED simulation for idx=65
# Skipping SED simulation for idx=66
# Skipping SED simulation for idx=67
# Skipping SED simulation for idx=68
# Skipping SED simulation for idx=69
# Skipping SED simulation for idx=70
# Skipping SED simulation for idx=71
# Skipping SED simulation for idx=72
# Skipping SED simulation for idx=73
# Skipping SED simulation for idx=74
# Skipping SED simulation for idx=75
# Skipping SED simulation for idx=76
# Skipping SED simulation for idx=77
# Skipping SED simulation for idx=78
# Skipping SED simulation for idx=79
# Skipping SED simulation for idx=80
# Skipping SED simulation for idx=81
# Skipping SED simulation for idx=82
# Skipping SED simulation for idx=83
# Skipping SED simulation for idx=84
# Skipping SED simulation for idx=85
# Skipping SED simulation for idx=86
# Skipping SED simulation for idx=87
# Skipping SED simulation for idx=88
# Skipping SED simulation for idx=89
# Skipping SED simulation for idx=90
# Skipping SED simulation for idx=91
# Skipping SED simulation for idx=92
# Skipping SED simulation for idx=93
# Skipping SED simulation for idx=94
# Skipping SED simulation for idx=95
# Skipping SED simulation for idx=96
# Skipping SED simulation for idx=97
# Skipping SED simulation for idx=98
# Skipping SED simulation for idx=99
# Skipping SED simulation for idx=100
# Skipping SED simulation for idx=101
# Skipping SED simulation for idx=102
# Skipping SED simulation for idx=103
# Skipping SED simulation for idx=104
# Skipping SED simulation for idx=105
# Skipping SED simulation for idx=106
# Skipping SED simulation for idx=107
# Skipping SED simulation for idx=108
# Skipping SED simulation for idx=109
# Skipping SED simulation for idx=110
# Skipping SED simulation for idx=111
# Skipping SED simulation for idx=112
# Skipping SED simulation for idx=113
# Skipping SED simulation for idx=114
# Skipping SED simulation for idx=115
# Skipping SED simulation for idx=116
# Skipping SED simulation for idx=117
# Skipping SED simulation for idx=118
# Skipping SED simulation for idx=119
# Skipping SED simulation for idx=120
# Skipping SED simulation for idx=121
# Skipping SED simulation for idx=122
# Skipping SED simulation for idx=123
# Skipping SED simulation for idx=124
# Skipping SED simulation for idx=125
# Skipping SED simulation for idx=126
# Skipping SED simulation for idx=127
# Skipping SED simulation for idx=128
# Skipping SED simulation for idx=129
# Skipping SED simulation for idx=130
# Skipping SED simulation for idx=131
# Skipping SED simulation for idx=132
# Skipping SED simulation for idx=133
# Skipping SED simulation for idx=134
# Skipping SED simulation for idx=135
# Skipping SED simulation for idx=136
# Skipping SED simulation for idx=137
# Skipping SED simulation for idx=138
# Skipping SED simulation for idx=139
# Skipping SED simulation for idx=140
# Skipping SED simulation for idx=141
# Skipping SED simulation for idx=142
# Skipping SED simulation for idx=143
# Skipping SED simulation for idx=144
# Skipping SED simulation for idx=145
# Skipping SED simulation for idx=146
# Skipping SED simulation for idx=147
# Skipping SED simulation for idx=148
# Skipping SED simulation for idx=149
# Skipping SED simulation for idx=150
# Skipping SED simulation for idx=151
# Skipping SED simulation for idx=152
# Skipping SED simulation for idx=153
# Skipping SED simulation for idx=154
# Skipping SED simulation for idx=155
# Skipping SED simulation for idx=156
# Skipping SED simulation for idx=157
# Skipping SED simulation for idx=158
# Skipping SED simulation for idx=159
# Skipping SED simulation for idx=160
# Skipping SED simulation for idx=161
# Skipping SED simulation for idx=162
# Skipping SED simulation for idx=163
# Skipping SED simulation for idx=164
# Skipping SED simulation for idx=165
# Skipping SED simulation for idx=166
# Skipping SED simulation for idx=167
# Skipping SED simulation for idx=168
# Skipping SED simulation for idx=169
# Skipping SED simulation for idx=170
# Skipping SED simulation for idx=171
# Skipping SED simulation for idx=172
# Skipping SED simulation for idx=173
# Skipping SED simulation for idx=174
# Skipping SED simulation for idx=175
# Skipping SED simulation for idx=176
# Skipping SED simulation for idx=177
# Skipping SED simulation for idx=178
# Skipping SED simulation for idx=179
# Skipping SED simulation for idx=180
# Skipping SED simulation for idx=181
# Skipping SED simulation for idx=182
# Skipping SED simulation for idx=183
# Skipping SED simulation for idx=184
# Skipping SED simulation for idx=185
# Skipping SED simulation for idx=186
# Skipping SED simulation for idx=187
# Skipping SED simulation for idx=188
# Skipping SED simulation for idx=189
# Skipping SED simulation for idx=190
# Skipping SED simulation for idx=191
# Skipping SED simulation for idx=192
# Skipping SED simulation for idx=193
# Skipping SED simulation for idx=194
# Skipping SED simulation for idx=195
# Skipping SED simulation for idx=196
# Skipping SED simulation for idx=197
# Skipping SED simulation for idx=198
# Skipping SED simulation for idx=199
# Skipping SED simulation for idx=200
# Skipping SED simulation for idx=201
# Skipping SED simulation for idx=202
# Skipping SED simulation for idx=203
# Skipping SED simulation for idx=204
# Skipping SED simulation for idx=205
# Skipping SED simulation for idx=206
# Skipping SED simulation for idx=207
# Skipping SED simulation for idx=208
# Skipping SED simulation for idx=209
# Skipping SED simulation for idx=210
# Skipping SED simulation for idx=211
# Skipping SED simulation for idx=212
# Skipping SED simulation for idx=213
# Skipping SED simulation for idx=214
# Skipping SED simulation for idx=215
# Skipping SED simulation for idx=216
# Skipping SED simulation for idx=217
# Skipping SED simulation for idx=218
# Skipping SED simulation for idx=219
# Skipping SED simulation for idx=220
# Skipping SED simulation for idx=221
# Skipping SED simulation for idx=222
# Skipping SED simulation for idx=223
# Skipping SED simulation for idx=224
# Skipping SED simulation for idx=225
# Skipping SED simulation for idx=226
# Skipping SED simulation for idx=227
# Skipping SED simulation for idx=228
# Skipping SED simulation for idx=229
# Skipping SED simulation for idx=230
# Skipping SED simulation for idx=231
# Skipping SED simulation for idx=232
# Skipping SED simulation for idx=233
# Skipping SED simulation for idx=234
# Skipping SED simulation for idx=235
# Skipping SED simulation for idx=236
# Skipping SED simulation for idx=237
# Skipping SED simulation for idx=238
# Skipping SED simulation for idx=239
# Skipping SED simulation for idx=240
# Skipping SED simulation for idx=241
# Skipping SED simulation for idx=242
# Skipping SED simulation for idx=243
# Skipping SED simulation for idx=244
# Skipping SED simulation for idx=245
# Skipping SED simulation for idx=246
# Skipping SED simulation for idx=247
# Skipping SED simulation for idx=248
# Skipping SED simulation for idx=249
# Skipping SED simulation for idx=250
# Skipping SED simulation for idx=251
# Skipping SED simulation for idx=252
# Skipping SED simulation for idx=253
# Skipping SED simulation for idx=254
# Skipping SED simulation for idx=255
# Skipping SED simulation for idx=256
# Skipping SED simulation for idx=257
# Skipping SED simulation for idx=258
# Skipping SED simulation for idx=259
# Skipping SED simulation for idx=260
# Skipping SED simulation for idx=261
# Skipping SED simulation for idx=262
# Skipping SED simulation for idx=263
# Skipping SED simulation for idx=264
# Skipping SED simulation for idx=265
# Skipping SED simulation for idx=266
# Skipping SED simulation for idx=267
# Skipping SED simulation for idx=268
# Skipping SED simulation for idx=269
# Skipping SED simulation for idx=270
# Skipping SED simulation for idx=271
# Skipping SED simulation for idx=272
# Skipping SED simulation for idx=273
# Skipping SED simulation for idx=274
# Skipping SED simulation for idx=275
# Skipping SED simulation for idx=276
# Skipping SED simulation for idx=277
# Skipping SED simulation for idx=278
# Skipping SED simulation for idx=279
# Skipping SED simulation for idx=280
# Skipping SED simulation for idx=281
# Skipping SED simulation for idx=282
# Skipping SED simulation for idx=283
# Skipping SED simulation for idx=284
# Skipping SED simulation for idx=285
# Skipping SED simulation for idx=286
# Skipping SED simulation for idx=287
# Skipping SED simulation for idx=288
# Skipping SED simulation for idx=289
# Skipping SED simulation for idx=290
# Skipping SED simulation for idx=291
# Skipping SED simulation for idx=292
# Skipping SED simulation for idx=293
# Skipping SED simulation for idx=294
# Skipping SED simulation for idx=295
# Skipping SED simulation for idx=296
# Skipping SED simulation for idx=297
# Skipping SED simulation for idx=298
# Skipping SED simulation for idx=299
# Skipping SED simulation for idx=300
# Skipping SED simulation for idx=301
# Skipping SED simulation for idx=302
# Skipping SED simulation for idx=303
# Skipping SED simulation for idx=304
# Skipping SED simulation for idx=305
# Skipping SED simulation for idx=306
# Skipping SED simulation for idx=307
# Skipping SED simulation for idx=308
# Skipping SED simulation for idx=309
# Skipping SED simulation for idx=310
# Skipping SED simulation for idx=311
# Skipping SED simulation for idx=312
# Skipping SED simulation for idx=313
# Skipping SED simulation for idx=314
# Skipping SED simulation for idx=315
# Skipping SED simulation for idx=316
# Skipping SED simulation for idx=317
# Skipping SED simulation for idx=318
# Skipping SED simulation for idx=319
# Skipping SED simulation for idx=320
# Skipping SED simulation for idx=321
# Skipping SED simulation for idx=322
# Skipping SED simulation for idx=323
# Skipping SED simulation for idx=324
# Skipping SED simulation for idx=325
# Skipping SED simulation for idx=326
# Skipping SED simulation for idx=327
# Skipping SED simulation for idx=328
# Skipping SED simulation for idx=329
# Skipping SED simulation for idx=330
# Skipping SED simulation for idx=331
# Skipping SED simulation for idx=332
# Skipping SED simulation for idx=333
# Skipping SED simulation for idx=334
# Skipping SED simulation for idx=335
# Skipping SED simulation for idx=336
# Skipping SED simulation for idx=337
# Skipping SED simulation for idx=338
# Skipping SED simulation for idx=339
# Skipping SED simulation for idx=340
# Skipping SED simulation for idx=341
# Skipping SED simulation for idx=342
# Skipping SED simulation for idx=343
# Skipping SED simulation for idx=344
# Skipping SED simulation for idx=345
# Skipping SED simulation for idx=346
# Skipping SED simulation for idx=347
# Skipping SED simulation for idx=348
# Skipping SED simulation for idx=349
# Skipping SED simulation for idx=350
# Skipping SED simulation for idx=351
# Skipping SED simulation for idx=352
# Skipping SED simulation for idx=353
# Skipping SED simulation for idx=354
# Skipping SED simulation for idx=355
# Skipping SED simulation for idx=356
# Skipping SED simulation for idx=357
# Skipping SED simulation for idx=358
# Skipping SED simulation for idx=359
# Skipping SED simulation for idx=360
# Skipping SED simulation for idx=361
# Skipping SED simulation for idx=362
# Skipping SED simulation for idx=363
# Skipping SED simulation for idx=364
# Skipping SED simulation for idx=365
# Skipping SED simulation for idx=366
# Skipping SED simulation for idx=367
# Skipping SED simulation for idx=368
# Skipping SED simulation for idx=369
# Skipping SED simulation for idx=370
# Skipping SED simulation for idx=371
# Skipping SED simulation for idx=372
# Skipping SED simulation for idx=373
# Skipping SED simulation for idx=374
# Skipping SED simulation for idx=375
# Skipping SED simulation for idx=376
# Skipping SED simulation for idx=377
# Skipping SED simulation for idx=378
# Skipping SED simulation for idx=379
# Skipping SED simulation for idx=380
# Skipping SED simulation for idx=381
# Skipping SED simulation for idx=382
# Skipping SED simulation for idx=383
# Skipping SED simulation for idx=384
# Skipping SED simulation for idx=385
# Skipping SED simulation for idx=386
# Skipping SED simulation for idx=387
# Skipping SED simulation for idx=388
# Skipping SED simulation for idx=389
# Skipping SED simulation for idx=390
# Skipping SED simulation for idx=391
# Skipping SED simulation for idx=392
# Skipping SED simulation for idx=393
# Skipping SED simulation for idx=394
# Skipping SED simulation for idx=395
# Skipping SED simulation for idx=396
# Skipping SED simulation for idx=397
# Skipping SED simulation for idx=398
# Skipping SED simulation for idx=399
# Skipping SED simulation for idx=400
# Skipping SED simulation for idx=401
# Skipping SED simulation for idx=402
# Skipping SED simulation for idx=403
# Skipping SED simulation for idx=404
# Skipping SED simulation for idx=405
# Skipping SED simulation for idx=406
# Skipping SED simulation for idx=407
# Skipping SED simulation for idx=408
# Skipping SED simulation for idx=409
# Skipping SED simulation for idx=410
# Skipping SED simulation for idx=411
# Skipping SED simulation for idx=412
# Skipping SED simulation for idx=413
# Skipping SED simulation for idx=414
# Skipping SED simulation for idx=415
# Skipping SED simulation for idx=416
# Skipping SED simulation for idx=417
# Skipping SED simulation for idx=418
# Skipping SED simulation for idx=419
# Skipping SED simulation for idx=420
# Skipping SED simulation for idx=421
# Skipping SED simulation for idx=422
# Skipping SED simulation for idx=423
# Skipping SED simulation for idx=424
# Skipping SED simulation for idx=425
# Skipping SED simulation for idx=426
# Skipping SED simulation for idx=427
# Skipping SED simulation for idx=428
# Skipping SED simulation for idx=429
# Skipping SED simulation for idx=430
# Skipping SED simulation for idx=431
# Skipping SED simulation for idx=432
# Skipping SED simulation for idx=433
# Skipping SED simulation for idx=434
# Skipping SED simulation for idx=435
# Skipping SED simulation for idx=436
# Skipping SED simulation for idx=437
# Skipping SED simulation for idx=438
# Skipping SED simulation for idx=439
# Skipping SED simulation for idx=440
# Skipping SED simulation for idx=441
# Skipping SED simulation for idx=442
# Skipping SED simulation for idx=443
# Skipping SED simulation for idx=444
# Skipping SED simulation for idx=445
# Skipping SED simulation for idx=446
# Skipping SED simulation for idx=447
# Skipping SED simulation for idx=448
# Skipping SED simulation for idx=449
# Skipping SED simulation for idx=450
# Skipping SED simulation for idx=451
# Skipping SED simulation for idx=452
# Skipping SED simulation for idx=453
# Skipping SED simulation for idx=454
# Skipping SED simulation for idx=455
# Skipping SED simulation for idx=456
# Skipping SED simulation for idx=457
# Skipping SED simulation for idx=458
# Skipping SED simulation for idx=459
# Skipping SED simulation for idx=460
# Skipping SED simulation for idx=461
# Skipping SED simulation for idx=462
# Skipping SED simulation for idx=463
# Skipping SED simulation for idx=464
# Skipping SED simulation for idx=465
# Skipping SED simulation for idx=466
# Skipping SED simulation for idx=467
# Skipping SED simulation for idx=468
# Skipping SED simulation for idx=469
# Skipping SED simulation for idx=470
# Skipping SED simulation for idx=471
# Skipping SED simulation for idx=472
# Skipping SED simulation for idx=473
# Skipping SED simulation for idx=474
# Skipping SED simulation for idx=475
# Skipping SED simulation for idx=476
# Skipping SED simulation for idx=477
# Skipping SED simulation for idx=478
# Skipping SED simulation for idx=479
# Skipping SED simulation for idx=480
# Skipping SED simulation for idx=481
# Skipping SED simulation for idx=482
# Skipping SED simulation for idx=483
# Skipping SED simulation for idx=484
# Skipping SED simulation for idx=485
# Skipping SED simulation for idx=486
# Skipping SED simulation for idx=487
# Skipping SED simulation for idx=488
# Skipping SED simulation for idx=489
# Skipping SED simulation for idx=490
# Skipping SED simulation for idx=491
# Skipping SED simulation for idx=492
# Skipping SED simulation for idx=493
# Skipping SED simulation for idx=494
# Skipping SED simulation for idx=495
# Skipping SED simulation for idx=496
# Skipping SED simulation for idx=497
# Skipping SED simulation for idx=498
# Skipping SED simulation for idx=499
# Skipping SED simulation for idx=500
# Skipping SED simulation for idx=501
# Skipping SED simulation for idx=502
# Skipping SED simulation for idx=503
# Skipping SED simulation for idx=504
# Skipping SED simulation for idx=505
# Skipping SED simulation for idx=506
# Skipping SED simulation for idx=507
# Skipping SED simulation for idx=508
# Skipping SED simulation for idx=509
# Skipping SED simulation for idx=510
# Skipping SED simulation for idx=511
# Skipping SED simulation for idx=512
# Skipping SED simulation for idx=513
# Skipping SED simulation for idx=514
# Skipping SED simulation for idx=515
# Skipping SED simulation for idx=516
# Skipping SED simulation for idx=517
# Skipping SED simulation for idx=518
# Skipping SED simulation for idx=519
# Skipping SED simulation for idx=520
# Skipping SED simulation for idx=521
# Skipping SED simulation for idx=522
# Skipping SED simulation for idx=523
# Skipping SED simulation for idx=524
# Skipping SED simulation for idx=525
# Skipping SED simulation for idx=526
# Skipping SED simulation for idx=527
# Skipping SED simulation for idx=528
# Skipping SED simulation for idx=529
# Skipping SED simulation for idx=530
# Skipping SED simulation for idx=531
# Skipping SED simulation for idx=532
# Skipping SED simulation for idx=533
# Skipping SED simulation for idx=534
# Skipping SED simulation for idx=535
# Skipping SED simulation for idx=536
# Skipping SED simulation for idx=537
# Skipping SED simulation for idx=538
# Skipping SED simulation for idx=539
# Skipping SED simulation for idx=540
# Skipping SED simulation for idx=541
# Skipping SED simulation for idx=542
# Skipping SED simulation for idx=543
# Skipping SED simulation for idx=544
# Skipping SED simulation for idx=545
# Skipping SED simulation for idx=546
# Skipping SED simulation for idx=547
# Skipping SED simulation for idx=548
# Skipping SED simulation for idx=549
# Skipping SED simulation for idx=550
# Skipping SED simulation for idx=551
# Skipping SED simulation for idx=552
# Skipping SED simulation for idx=553
# Skipping SED simulation for idx=554
# Skipping SED simulation for idx=555
# Skipping SED simulation for idx=556
# Skipping SED simulation for idx=557
# Skipping SED simulation for idx=558
# Skipping SED simulation for idx=559
# Skipping SED simulation for idx=560
# Skipping SED simulation for idx=561
# Skipping SED simulation for idx=562
# Skipping SED simulation for idx=563
# Skipping SED simulation for idx=564
# Skipping SED simulation for idx=565
# Skipping SED simulation for idx=566
# Skipping SED simulation for idx=567
# Skipping SED simulation for idx=568
# Skipping SED simulation for idx=569
# Skipping SED simulation for idx=570
# Skipping SED simulation for idx=571
# Skipping SED simulation for idx=572
# Skipping SED simulation for idx=573
# Skipping SED simulation for idx=574
# Skipping SED simulation for idx=575
# Skipping SED simulation for idx=576
# Skipping SED simulation for idx=577
# Skipping SED simulation for idx=578
# Skipping SED simulation for idx=579
# Skipping SED simulation for idx=580
# Skipping SED simulation for idx=581
# Skipping SED simulation for idx=582
# Skipping SED simulation for idx=583
# Skipping SED simulation for idx=584
# Skipping SED simulation for idx=585
# Skipping SED simulation for idx=586
# Skipping SED simulation for idx=587
# Skipping SED simulation for idx=588
# Skipping SED simulation for idx=589
# Skipping SED simulation for idx=590
# Skipping SED simulation for idx=591
# Skipping SED simulation for idx=592
# Skipping SED simulation for idx=593
# Skipping SED simulation for idx=594
# Skipping SED simulation for idx=595
# Skipping SED simulation for idx=596
# Skipping SED simulation for idx=597
# Skipping SED simulation for idx=598
# Skipping SED simulation for idx=599
# Skipping SED simulation for idx=600
# Skipping SED simulation for idx=601
# Skipping SED simulation for idx=602
# Skipping SED simulation for idx=603
# Skipping SED simulation for idx=604
# Skipping SED simulation for idx=605
# Skipping SED simulation for idx=606
# Skipping SED simulation for idx=607
# Skipping SED simulation for idx=608
# Skipping SED simulation for idx=609
# Skipping SED simulation for idx=610
# Skipping SED simulation for idx=611
# Skipping SED simulation for idx=612
# Skipping SED simulation for idx=613
# Skipping SED simulation for idx=614
# Skipping SED simulation for idx=615
# Skipping SED simulation for idx=616
# Skipping SED simulation for idx=617
# Skipping SED simulation for idx=618
# Skipping SED simulation for idx=619
# Skipping SED simulation for idx=620
# Skipping SED simulation for idx=621
# Skipping SED simulation for idx=622
# Skipping SED simulation for idx=623
# Skipping SED simulation for idx=624
# Skipping SED simulation for idx=625
# Skipping SED simulation for idx=626
# Skipping SED simulation for idx=627
# Skipping SED simulation for idx=628
# Skipping SED simulation for idx=629
# Skipping SED simulation for idx=630
# Skipping SED simulation for idx=631
# Skipping SED simulation for idx=632
# Skipping SED simulation for idx=633
# Skipping SED simulation for idx=634
# Skipping SED simulation for idx=635
# Skipping SED simulation for idx=636
# Skipping SED simulation for idx=637
# Skipping SED simulation for idx=638
# Skipping SED simulation for idx=639
# Skipping SED simulation for idx=640
# Skipping SED simulation for idx=641
# Skipping SED simulation for idx=642
# Skipping SED simulation for idx=643
# Skipping SED simulation for idx=644
# Skipping SED simulation for idx=645
# Skipping SED simulation for idx=646
# Skipping SED simulation for idx=647
# Skipping SED simulation for idx=648
# Skipping SED simulation for idx=649
# Skipping SED simulation for idx=650
# Skipping SED simulation for idx=651
# Skipping SED simulation for idx=652
# Skipping SED simulation for idx=653
# Skipping SED simulation for idx=654
# Skipping SED simulation for idx=655
# Skipping SED simulation for idx=656
# Skipping SED simulation for idx=657
# Skipping SED simulation for idx=658
# Skipping SED simulation for idx=659
# Skipping SED simulation for idx=660
# Skipping SED simulation for idx=661
# Skipping SED simulation for idx=662
# Skipping SED simulation for idx=663
# Skipping SED simulation for idx=664
# Skipping SED simulation for idx=665
# Skipping SED simulation for idx=666
# Skipping SED simulation for idx=667
# Skipping SED simulation for idx=668
# Skipping SED simulation for idx=669
# Skipping SED simulation for idx=670
# Skipping SED simulation for idx=671
# Skipping SED simulation for idx=672
# Skipping SED simulation for idx=673
# Skipping SED simulation for idx=674
# Skipping SED simulation for idx=675
# Skipping SED simulation for idx=676
# Skipping SED simulation for idx=677
# Skipping SED simulation for idx=678
# Skipping SED simulation for idx=679
# Skipping SED simulation for idx=680
# Skipping SED simulation for idx=681
# Skipping SED simulation for idx=682
# Skipping SED simulation for idx=683
# Skipping SED simulation for idx=684
# Skipping SED simulation for idx=685
# Skipping SED simulation for idx=686
# Skipping SED simulation for idx=687
# Skipping SED simulation for idx=688
# Skipping SED simulation for idx=689
# Skipping SED simulation for idx=690
# Skipping SED simulation for idx=691
# Skipping SED simulation for idx=692
# Skipping SED simulation for idx=693
# Skipping SED simulation for idx=694
# Skipping SED simulation for idx=695
# Skipping SED simulation for idx=696
# Skipping SED simulation for idx=697
# Skipping SED simulation for idx=698
# Skipping SED simulation for idx=699
# Skipping SED simulation for idx=700
# Skipping SED simulation for idx=701
# Skipping SED simulation for idx=702
# Skipping SED simulation for idx=703
# Skipping SED simulation for idx=704
# Skipping SED simulation for idx=705
# Skipping SED simulation for idx=706
# Skipping SED simulation for idx=707
# Skipping SED simulation for idx=708
# Skipping SED simulation for idx=709
# Skipping SED simulation for idx=710
# Skipping SED simulation for idx=711
# Skipping SED simulation for idx=712
# Skipping SED simulation for idx=713
# Skipping SED simulation for idx=714
# Skipping SED simulation for idx=715
# Skipping SED simulation for idx=716
# Skipping SED simulation for idx=717
# Skipping SED simulation for idx=718
# Skipping SED simulation for idx=719
# Skipping SED simulation for idx=720
# Skipping SED simulation for idx=721
# Skipping SED simulation for idx=722
# Skipping SED simulation for idx=723
# Skipping SED simulation for idx=724
# Skipping SED simulation for idx=725
# Skipping SED simulation for idx=726
# Skipping SED simulation for idx=727
# Skipping SED simulation for idx=728
# Skipping SED simulation for idx=729
# Skipping SED simulation for idx=730
# Skipping SED simulation for idx=731
# Skipping SED simulation for idx=732
# Skipping SED simulation for idx=733
# Skipping SED simulation for idx=734
# Skipping SED simulation for idx=735
# Skipping SED simulation for idx=736
# Skipping SED simulation for idx=737
# Skipping SED simulation for idx=738
# Skipping SED simulation for idx=739
# Skipping SED simulation for idx=740
# Skipping SED simulation for idx=741
# Skipping SED simulation for idx=742
# Skipping SED simulation for idx=743
# Skipping SED simulation for idx=744
# Skipping SED simulation for idx=745
# Skipping SED simulation for idx=746
# Skipping SED simulation for idx=747
# Skipping SED simulation for idx=748
# Skipping SED simulation for idx=749
# Skipping SED simulation for idx=750
# Skipping SED simulation for idx=751
# Skipping SED simulation for idx=752
# Skipping SED simulation for idx=753
# Skipping SED simulation for idx=754
# Skipping SED simulation for idx=755
# Skipping SED simulation for idx=756
# Skipping SED simulation for idx=757
# Skipping SED simulation for idx=758
# Skipping SED simulation for idx=759
# Skipping SED simulation for idx=760
# Skipping SED simulation for idx=761
# Skipping SED simulation for idx=762
# Skipping SED simulation for idx=763
# Skipping SED simulation for idx=764
# Skipping SED simulation for idx=765
# Skipping SED simulation for idx=766
# Skipping SED simulation for idx=767
# Skipping SED simulation for idx=768
# Skipping SED simulation for idx=769
# Skipping SED simulation for idx=770
# Skipping SED simulation for idx=771
# Skipping SED simulation for idx=772
# Skipping SED simulation for idx=773
# Skipping SED simulation for idx=774
# Skipping SED simulation for idx=775
# Skipping SED simulation for idx=776
# Skipping SED simulation for idx=777
# Skipping SED simulation for idx=778
# Skipping SED simulation for idx=779
# Skipping SED simulation for idx=780
# Skipping SED simulation for idx=781
# Skipping SED simulation for idx=782
# Skipping SED simulation for idx=783
# Skipping SED simulation for idx=784
# Skipping SED simulation for idx=785
# Skipping SED simulation for idx=786
# Skipping SED simulation for idx=787
# Skipping SED simulation for idx=788
# Skipping SED simulation for idx=789
# Skipping SED simulation for idx=790
# Skipping SED simulation for idx=791
# Skipping SED simulation for idx=792
# Skipping SED simulation for idx=793
# Skipping SED simulation for idx=794
# Skipping SED simulation for idx=795
# Skipping SED simulation for idx=796
# Skipping SED simulation for idx=797
# Skipping SED simulation for idx=798
# Skipping SED simulation for idx=799
# Skipping SED simulation for idx=800
# Skipping SED simulation for idx=801
# Skipping SED simulation for idx=802
# Skipping SED simulation for idx=803
# Skipping SED simulation for idx=804
# Skipping SED simulation for idx=805
# Skipping SED simulation for idx=806
# Skipping SED simulation for idx=807
# Skipping SED simulation for idx=808
# Skipping SED simulation for idx=809
# Skipping SED simulation for idx=810
# Skipping SED simulation for idx=811
# Skipping SED simulation for idx=812
# Skipping SED simulation for idx=813
# Skipping SED simulation for idx=814
# Skipping SED simulation for idx=815
# Skipping SED simulation for idx=816
# Skipping SED simulation for idx=817
# Skipping SED simulation for idx=818
# Skipping SED simulation for idx=819
# Skipping SED simulation for idx=820
# Skipping SED simulation for idx=821
# Skipping SED simulation for idx=822
# Skipping SED simulation for idx=823
# Skipping SED simulation for idx=824
# Skipping SED simulation for idx=825
# Skipping SED simulation for idx=826
# Skipping SED simulation for idx=827
# Skipping SED simulation for idx=828
# Skipping SED simulation for idx=829
# Skipping SED simulation for idx=830
# Skipping SED simulation for idx=831
# Skipping SED simulation for idx=832
# Skipping SED simulation for idx=833
# Skipping SED simulation for idx=834
# Skipping SED simulation for idx=835
# Skipping SED simulation for idx=836
# Skipping SED simulation for idx=837
# Skipping SED simulation for idx=838
# Skipping SED simulation for idx=839
# Skipping SED simulation for idx=840
# Skipping SED simulation for idx=841
# Skipping SED simulation for idx=842
# Skipping SED simulation for idx=843
# Skipping SED simulation for idx=844
# Skipping SED simulation for idx=845
# Skipping SED simulation for idx=846
# Skipping SED simulation for idx=847
# Skipping SED simulation for idx=848
# Skipping SED simulation for idx=849
# Skipping SED simulation for idx=850
# Skipping SED simulation for idx=851
# Skipping SED simulation for idx=852
# Skipping SED simulation for idx=853
# Skipping SED simulation for idx=854
# Skipping SED simulation for idx=855
# Skipping SED simulation for idx=856
# Skipping SED simulation for idx=857
# Skipping SED simulation for idx=858
# Skipping SED simulation for idx=859
# Skipping SED simulation for idx=860
# Skipping SED simulation for idx=861
# Skipping SED simulation for idx=862
# Skipping SED simulation for idx=863
# Skipping SED simulation for idx=864
# Skipping SED simulation for idx=865
# Skipping SED simulation for idx=866
# Skipping SED simulation for idx=867
# Skipping SED simulation for idx=868
# Skipping SED simulation for idx=869
# Skipping SED simulation for idx=870
# Skipping SED simulation for idx=871
# Skipping SED simulation for idx=872
# Skipping SED simulation for idx=873
# Skipping SED simulation for idx=874
# Skipping SED simulation for idx=875
# Skipping SED simulation for idx=876
# Skipping SED simulation for idx=877
# Skipping SED simulation for idx=878
# Skipping SED simulation for idx=879
# Skipping SED simulation for idx=880
# Skipping SED simulation for idx=881
# Skipping SED simulation for idx=882
# Skipping SED simulation for idx=883
# Skipping SED simulation for idx=884
# Skipping SED simulation for idx=885
# Skipping SED simulation for idx=886
# Skipping SED simulation for idx=887
# Skipping SED simulation for idx=888
# Skipping SED simulation for idx=889
# Skipping SED simulation for idx=890
# Skipping SED simulation for idx=891
# Skipping SED simulation for idx=892
# Skipping SED simulation for idx=893
# Skipping SED simulation for idx=894
# Skipping SED simulation for idx=895
# Skipping SED simulation for idx=896
# Skipping SED simulation for idx=897
# Skipping SED simulation for idx=898
# Skipping SED simulation for idx=899
# Skipping SED simulation for idx=900
# Skipping SED simulation for idx=901
# Skipping SED simulation for idx=902
# Skipping SED simulation for idx=903
# Skipping SED simulation for idx=904
# Skipping SED simulation for idx=905
# Skipping SED simulation for idx=906
# Skipping SED simulation for idx=907
# Skipping SED simulation for idx=908
# Skipping SED simulation for idx=909
# Skipping SED simulation for idx=910
# Skipping SED simulation for idx=911
# Skipping SED simulation for idx=912
# Skipping SED simulation for idx=913
# Skipping SED simulation for idx=914
# Skipping SED simulation for idx=915
# Skipping SED simulation for idx=916
# Skipping SED simulation for idx=917
# Skipping SED simulation for idx=918
# Skipping SED simulation for idx=919
# Skipping SED simulation for idx=920
# Skipping SED simulation for idx=921
# Skipping SED simulation for idx=922
# Skipping SED simulation for idx=923
# Skipping SED simulation for idx=924
# Skipping SED simulation for idx=925
# Skipping SED simulation for idx=926
# Skipping SED simulation for idx=927
# Skipping SED simulation for idx=928
# Skipping SED simulation for idx=929
# Skipping SED simulation for idx=930
# Skipping SED simulation for idx=931
# Skipping SED simulation for idx=932
# Skipping SED simulation for idx=933
# Skipping SED simulation for idx=934
# Skipping SED simulation for idx=935
# Skipping SED simulation for idx=936
# Skipping SED simulation for idx=937
# Skipping SED simulation for idx=938
# Skipping SED simulation for idx=939
# Skipping SED simulation for idx=940
# Skipping SED simulation for idx=941
# Skipping SED simulation for idx=942
# Skipping SED simulation for idx=943
# Skipping SED simulation for idx=944
# Skipping SED simulation for idx=945
# Skipping SED simulation for idx=946
# Skipping SED simulation for idx=947
# Skipping SED simulation for idx=948
# Skipping SED simulation for idx=949
# Skipping SED simulation for idx=950
# Skipping SED simulation for idx=951
# Skipping SED simulation for idx=952
# Skipping SED simulation for idx=953
# Skipping SED simulation for idx=954
# Skipping SED simulation for idx=955
# Skipping SED simulation for idx=956
# Skipping SED simulation for idx=957
# Skipping SED simulation for idx=958
# Skipping SED simulation for idx=959
# Skipping SED simulation for idx=960
# Skipping SED simulation for idx=961
# Skipping SED simulation for idx=962
# Skipping SED simulation for idx=963
# Skipping SED simulation for idx=964
# Skipping SED simulation for idx=965
# Skipping SED simulation for idx=966
# Skipping SED simulation for idx=967
# Skipping SED simulation for idx=968
# Skipping SED simulation for idx=969
# Skipping SED simulation for idx=970
# Skipping SED simulation for idx=971
# Skipping SED simulation for idx=972
# Skipping SED simulation for idx=973
# Skipping SED simulation for idx=974
# Skipping SED simulation for idx=975
# Skipping SED simulation for idx=976
# Skipping SED simulation for idx=977
# Skipping SED simulation for idx=978
# Skipping SED simulation for idx=979
# Skipping SED simulation for idx=980
# Skipping SED simulation for idx=981
# Skipping SED simulation for idx=982
# Skipping SED simulation for idx=983
# Skipping SED simulation for idx=984
# Skipping SED simulation for idx=985
# Skipping SED simulation for idx=986
# Skipping SED simulation for idx=987
# Skipping SED simulation for idx=988
# Skipping SED simulation for idx=989
# Skipping SED simulation for idx=990
# Skipping SED simulation for idx=991
# Skipping SED simulation for idx=992
# Skipping SED simulation for idx=993
# Skipping SED simulation for idx=994
# Skipping SED simulation for idx=995
# Skipping SED simulation for idx=996
# Skipping SED simulation for idx=997
# Skipping SED simulation for idx=998
# Skipping SED simulation for idx=999
# Skipping SED simulation for idx=1000
# Skipping SED simulation for idx=1001
# Skipping SED simulation for idx=1002
# Skipping SED simulation for idx=1003
# Skipping SED simulation for idx=1004
# Skipping SED simulation for idx=1005
# Skipping SED simulation for idx=1006
# Skipping SED simulation for idx=1007
# Skipping SED simulation for idx=1008
# Skipping SED simulation for idx=1009
# Skipping SED simulation for idx=1010
# Skipping SED simulation for idx=1011
# Skipping SED simulation for idx=1012
# Skipping SED simulation for idx=1013
# Skipping SED simulation for idx=1014
# Skipping SED simulation for idx=1015
# Skipping SED simulation for idx=1016
# Skipping SED simulation for idx=1017
# Skipping SED simulation for idx=1018
# Skipping SED simulation for idx=1019
# Skipping SED simulation for idx=1020
# Skipping SED simulation for idx=1021
# Skipping SED simulation for idx=1022
# Skipping SED simulation for idx=1023
# Skipping SED simulation for idx=1024
# Skipping SED simulation for idx=1025
# Skipping SED simulation for idx=1026
# Skipping SED simulation for idx=1027
# Skipping SED simulation for idx=1028
# Skipping SED simulation for idx=1029
# Skipping SED simulation for idx=1030
# Skipping SED simulation for idx=1031
# Skipping SED simulation for idx=1032
# Skipping SED simulation for idx=1033
# Skipping SED simulation for idx=1034
# Skipping SED simulation for idx=1035
# Skipping SED simulation for idx=1036
# Skipping SED simulation for idx=1037
# Skipping SED simulation for idx=1038
# Skipping SED simulation for idx=1039
# Skipping SED simulation for idx=1040
# Skipping SED simulation for idx=1041
# Skipping SED simulation for idx=1042
# Skipping SED simulation for idx=1043
# Skipping SED simulation for idx=1044
# Skipping SED simulation for idx=1045
# Skipping SED simulation for idx=1046
# Skipping SED simulation for idx=1047
# Skipping SED simulation for idx=1048
# Skipping SED simulation for idx=1049
# Skipping SED simulation for idx=1050
# Skipping SED simulation for idx=1051
# Skipping SED simulation for idx=1052
# Skipping SED simulation for idx=1053
# Skipping SED simulation for idx=1054
# Skipping SED simulation for idx=1055
# Skipping SED simulation for idx=1056
# Skipping SED simulation for idx=1057
# Skipping SED simulation for idx=1058
# Skipping SED simulation for idx=1059
# Skipping SED simulation for idx=1060
# Skipping SED simulation for idx=1061
# Skipping SED simulation for idx=1062
# Skipping SED simulation for idx=1063
# Skipping SED simulation for idx=1064
# Skipping SED simulation for idx=1065
# Skipping SED simulation for idx=1066
# Skipping SED simulation for idx=1067
# Skipping SED simulation for idx=1068
# Skipping SED simulation for idx=1069
# Skipping SED simulation for idx=1070
# Skipping SED simulation for idx=1071
# Skipping SED simulation for idx=1072
# Skipping SED simulation for idx=1073
# Skipping SED simulation for idx=1074
# Skipping SED simulation for idx=1075
# Skipping SED simulation for idx=1076
# Skipping SED simulation for idx=1077
# Skipping SED simulation for idx=1078
# Skipping SED simulation for idx=1079
# Skipping SED simulation for idx=1080
# Skipping SED simulation for idx=1081
# Skipping SED simulation for idx=1082
# Skipping SED simulation for idx=1083
# Skipping SED simulation for idx=1084
# Skipping SED simulation for idx=1085
# Skipping SED simulation for idx=1086
# Skipping SED simulation for idx=1087
# Skipping SED simulation for idx=1088
# Skipping SED simulation for idx=1089
# Skipping SED simulation for idx=1090
# Skipping SED simulation for idx=1091
# Skipping SED simulation for idx=1092
# Skipping SED simulation for idx=1093
# Skipping SED simulation for idx=1094
# Skipping SED simulation for idx=1095
# Skipping SED simulation for idx=1096
# Skipping SED simulation for idx=1097
# Skipping SED simulation for idx=1098
# Skipping SED simulation for idx=1099
# Skipping SED simulation for idx=1100
# Skipping SED simulation for idx=1101
# Skipping SED simulation for idx=1102
# Skipping SED simulation for idx=1103
# Skipping SED simulation for idx=1104
# Skipping SED simulation for idx=1105
# Skipping SED simulation for idx=1106
# Skipping SED simulation for idx=1107
# Skipping SED simulation for idx=1108
# Skipping SED simulation for idx=1109
# Skipping SED simulation for idx=1110
# Skipping SED simulation for idx=1111
# Skipping SED simulation for idx=1112
# Skipping SED simulation for idx=1113
# Skipping SED simulation for idx=1114
# Skipping SED simulation for idx=1115
# Skipping SED simulation for idx=1116
# Skipping SED simulation for idx=1117
# Skipping SED simulation for idx=1118
# Skipping SED simulation for idx=1119
# Skipping SED simulation for idx=1120
# Skipping SED simulation for idx=1121
# Skipping SED simulation for idx=1122
# Skipping SED simulation for idx=1123
# Skipping SED simulation for idx=1124
# Skipping SED simulation for idx=1125
# Skipping SED simulation for idx=1126
# Skipping SED simulation for idx=1127
# Skipping SED simulation for idx=1128
# Skipping SED simulation for idx=1129
# Skipping SED simulation for idx=1130
# Skipping SED simulation for idx=1131
# Skipping SED simulation for idx=1132
# Skipping SED simulation for idx=1133
# Skipping SED simulation for idx=1134
# Skipping SED simulation for idx=1135
# Skipping SED simulation for idx=1136
# Skipping SED simulation for idx=1137
# Skipping SED simulation for idx=1138
# Skipping SED simulation for idx=1139
# Skipping SED simulation for idx=1140
# Skipping SED simulation for idx=1141
# Skipping SED simulation for idx=1142
# Skipping SED simulation for idx=1143
# Skipping SED simulation for idx=1144
# Skipping SED simulation for idx=1145
# Skipping SED simulation for idx=1146
# Skipping SED simulation for idx=1147
# Skipping SED simulation for idx=1148
# Skipping SED simulation for idx=1149
# Skipping SED simulation for idx=1150
# Skipping SED simulation for idx=1151
# Skipping SED simulation for idx=1152
# Skipping SED simulation for idx=1153
# Skipping SED simulation for idx=1154
# Skipping SED simulation for idx=1155
# Skipping SED simulation for idx=1156
# Skipping SED simulation for idx=1157
# Skipping SED simulation for idx=1158
# Skipping SED simulation for idx=1159
# Skipping SED simulation for idx=1160
# Skipping SED simulation for idx=1161
# Skipping SED simulation for idx=1162
# Skipping SED simulation for idx=1163
# Skipping SED simulation for idx=1164
# Skipping SED simulation for idx=1165
# Skipping SED simulation for idx=1166
# Skipping SED simulation for idx=1167
# Skipping SED simulation for idx=1168
# Skipping SED simulation for idx=1169
# Skipping SED simulation for idx=1170
# Skipping SED simulation for idx=1171
# Skipping SED simulation for idx=1172
# Skipping SED simulation for idx=1173
# Skipping SED simulation for idx=1174
# Skipping SED simulation for idx=1175
# Skipping SED simulation for idx=1176
# Skipping SED simulation for idx=1177
# Skipping SED simulation for idx=1178
# Skipping SED simulation for idx=1179
# Skipping SED simulation for idx=1180
# Skipping SED simulation for idx=1181
# Skipping SED simulation for idx=1182
# Skipping SED simulation for idx=1183
# Skipping SED simulation for idx=1184
# Skipping SED simulation for idx=1185
# Skipping SED simulation for idx=1186
# Skipping SED simulation for idx=1187
# Skipping SED simulation for idx=1188
# Skipping SED simulation for idx=1189
# Skipping SED simulation for idx=1190
# Skipping SED simulation for idx=1191
# Skipping SED simulation for idx=1192
# Skipping SED simulation for idx=1193
# Skipping SED simulation for idx=1194
# Skipping SED simulation for idx=1195
# Skipping SED simulation for idx=1196
# Skipping SED simulation for idx=1197
# Skipping SED simulation for idx=1198
# Skipping SED simulation for idx=1199
# Skipping SED simulation for idx=1200
# Skipping SED simulation for idx=1201
# Skipping SED simulation for idx=1202
# Skipping SED simulation for idx=1203
# Skipping SED simulation for idx=1204
# Skipping SED simulation for idx=1205
# Skipping SED simulation for idx=1206
# Skipping SED simulation for idx=1207
# Skipping SED simulation for idx=1208
# Skipping SED simulation for idx=1209
# Skipping SED simulation for idx=1210
# Skipping SED simulation for idx=1211
# Skipping SED simulation for idx=1212
# Skipping SED simulation for idx=1213
# Skipping SED simulation for idx=1214
# Skipping SED simulation for idx=1215
# Skipping SED simulation for idx=1216
# Skipping SED simulation for idx=1217
# Skipping SED simulation for idx=1218
# Skipping SED simulation for idx=1219
# Skipping SED simulation for idx=1220
# Skipping SED simulation for idx=1221
# Skipping SED simulation for idx=1222
# Skipping SED simulation for idx=1223
# Skipping SED simulation for idx=1224
# Skipping SED simulation for idx=1225
# Skipping SED simulation for idx=1226
# Skipping SED simulation for idx=1227
# Skipping SED simulation for idx=1228
# Skipping SED simulation for idx=1229
# Skipping SED simulation for idx=1230
# Skipping SED simulation for idx=1231
# Skipping SED simulation for idx=1232
# Skipping SED simulation for idx=1233
# Skipping SED simulation for idx=1234
# Skipping SED simulation for idx=1235
# Skipping SED simulation for idx=1236
# Skipping SED simulation for idx=1237
# Skipping SED simulation for idx=1238
# Skipping SED simulation for idx=1239
# Skipping SED simulation for idx=1240
# Skipping SED simulation for idx=1241
# Skipping SED simulation for idx=1242
# Skipping SED simulation for idx=1243
# Skipping SED simulation for idx=1244
# Skipping SED simulation for idx=1245
# Skipping SED simulation for idx=1246
# Skipping SED simulation for idx=1247
# Skipping SED simulation for idx=1248
# Skipping SED simulation for idx=1249
# Skipping SED simulation for idx=1250
# Skipping SED simulation for idx=1251
# Skipping SED simulation for idx=1252
# Skipping SED simulation for idx=1253
# Skipping SED simulation for idx=1254
# Skipping SED simulation for idx=1255
# Skipping SED simulation for idx=1256
# Skipping SED simulation for idx=1257
# Skipping SED simulation for idx=1258
# Skipping SED simulation for idx=1259
# Skipping SED simulation for idx=1260
# Skipping SED simulation for idx=1261
# Skipping SED simulation for idx=1262
# Skipping SED simulation for idx=1263
# Skipping SED simulation for idx=1264
# Skipping SED simulation for idx=1265
# Skipping SED simulation for idx=1266
# Skipping SED simulation for idx=1267
# Skipping SED simulation for idx=1268
# Skipping SED simulation for idx=1269
# Skipping SED simulation for idx=1270
# Skipping SED simulation for idx=1271
# Skipping SED simulation for idx=1272
# Skipping SED simulation for idx=1273
# Skipping SED simulation for idx=1274
# Skipping SED simulation for idx=1275
# Skipping SED simulation for idx=1276
# Skipping SED simulation for idx=1277
# Skipping SED simulation for idx=1278
# Skipping SED simulation for idx=1279
# Skipping SED simulation for idx=1280
# Skipping SED simulation for idx=1281
# Skipping SED simulation for idx=1282
# Skipping SED simulation for idx=1283
# Skipping SED simulation for idx=1284
# Skipping SED simulation for idx=1285
# Skipping SED simulation for idx=1286
# Skipping SED simulation for idx=1287
# Skipping SED simulation for idx=1288
# Skipping SED simulation for idx=1289
# Skipping SED simulation for idx=1290
# Skipping SED simulation for idx=1291
# Skipping SED simulation for idx=1292
# Skipping SED simulation for idx=1293
# Skipping SED simulation for idx=1294
# Skipping SED simulation for idx=1295
# Skipping SED simulation for idx=1296
# Skipping SED simulation for idx=1297
# Skipping SED simulation for idx=1298
# Skipping SED simulation for idx=1299
# Skipping SED simulation for idx=1300
# Skipping SED simulation for idx=1301
# Skipping SED simulation for idx=1302
# Skipping SED simulation for idx=1303
# Skipping SED simulation for idx=1304
# Skipping SED simulation for idx=1305
# Skipping SED simulation for idx=1306
# Skipping SED simulation for idx=1307
# Skipping SED simulation for idx=1308
# Skipping SED simulation for idx=1309
# Skipping SED simulation for idx=1310
# Skipping SED simulation for idx=1311
# Skipping SED simulation for idx=1312
# Skipping SED simulation for idx=1313
# Skipping SED simulation for idx=1314
# Skipping SED simulation for idx=1315
# Skipping SED simulation for idx=1316
# Skipping SED simulation for idx=1317
# Skipping SED simulation for idx=1318
# Skipping SED simulation for idx=1319
# Skipping SED simulation for idx=1320
# Skipping SED simulation for idx=1321
# ...
# Skipping SED simulation for idx=30391
# Skipping SED simulation for idx=30392
# Skipping SED simulation for idx=30393
# Skipping SED simulation for idx=30394
# Skipping SED simulation for idx=30395
# Skipping SED simulation for idx=30396
# Skipping SED simulation for idx=30397
# Skipping SED simulation for idx=30398
# Skipping SED simulation for idx=30399
# Skipping SED simulation for idx=30400
# Skipping SED simulation for idx=30401
# Skipping SED simulation for idx=30402
# Skipping SED simulation for idx=30403
# Skipping SED simulation for idx=30404
# Skipping SED simulation for idx=30405
# Skipping SED simulation for idx=30406
# Skipping SED simulation for idx=30407
# Skipping SED simulation for idx=30408
# Skipping SED simulation for idx=30409
# Skipping SED simulation for idx=30410
# Skipping SED simulation for idx=30411
# Skipping SED simulation for idx=30412
# Skipping SED simulation for idx=30413
# Skipping SED simulation for idx=30414
# Skipping SED simulation for idx=30415
# Skipping SED simulation for idx=30416
# Skipping SED simulation for idx=30417
# Skipping SED simulation for idx=30418
# Skipping SED simulation for idx=30419
# Skipping SED simulation for idx=30420
# Skipping SED simulation for idx=30421
# Skipping SED simulation for idx=30422
# Skipping SED simulation for idx=30423
# Skipping SED simulation for idx=30424
# Skipping SED simulation for idx=30425
# Skipping SED simulation for idx=30426
# Skipping SED simulation for idx=30427
# Skipping SED simulation for idx=30428
# Skipping SED simulation for idx=30429
# Skipping SED simulation for idx=30430
# Skipping SED simulation for idx=30431
# Skipping SED simulation for idx=30432
# Skipping SED simulation for idx=30433
# Skipping SED simulation for idx=30434
# Skipping SED simulation for idx=30435
# Skipping SED simulation for idx=30436
# Skipping SED simulation for idx=30437
# Skipping SED simulation for idx=30438
# Skipping SED simulation for idx=30439
# Skipping SED simulation for idx=30440
# Skipping SED simulation for idx=30441
# Skipping SED simulation for idx=30442
# Skipping SED simulation for idx=30443
# Skipping SED simulation for idx=30444
# Skipping SED simulation for idx=30445
# Skipping SED simulation for idx=30446
# Skipping SED simulation for idx=30447
# Skipping SED simulation for idx=30448
# Skipping SED simulation for idx=30449
# Skipping SED simulation for idx=30450
# Skipping SED simulation for idx=30451
# Skipping SED simulation for idx=30452
# Skipping SED simulation for idx=30453
# Skipping SED simulation for idx=30454
# Skipping SED simulation for idx=30455
# Skipping SED simulation for idx=30456
# Skipping SED simulation for idx=30457
# Skipping SED simulation for idx=30458
# Skipping SED simulation for idx=30459
# Skipping SED simulation for idx=30460
# Skipping SED simulation for idx=30461
# Skipping SED simulation for idx=30462
# Skipping SED simulation for idx=30463
# Skipping SED simulation for idx=30464
# Skipping SED simulation for idx=30465
# Skipping SED simulation for idx=30466
# Skipping SED simulation for idx=30467
# Skipping SED simulation for idx=30468
# Skipping SED simulation for idx=30469
# Skipping SED simulation for idx=30470
# Skipping SED simulation for idx=30471
# Skipping SED simulation for idx=30472
# Skipping SED simulation for idx=30473
# Skipping SED simulation for idx=30474
# Skipping SED simulation for idx=30475
# Skipping SED simulation for idx=30476
# Skipping SED simulation for idx=30477
# Skipping SED simulation for idx=30478
# Skipping SED simulation for idx=30479
# Skipping SED simulation for idx=30480
# Skipping SED simulation for idx=30481
# Skipping SED simulation for idx=30482
# Skipping SED simulation for idx=30483
# Skipping SED simulation for idx=30484
# Skipping SED simulation for idx=30485
# Skipping SED simulation for idx=30486
# Skipping SED simulation for idx=30487
# Skipping SED simulation for idx=30488
# Skipping SED simulation for idx=30489
# Skipping SED simulation for idx=30490
# Skipping SED simulation for idx=30491
# Skipping SED simulation for idx=30492
# Skipping SED simulation for idx=30493
# Skipping SED simulation for idx=30494
# Skipping SED simulation for idx=30495
# Skipping SED simulation for idx=30496
# Skipping SED simulation for idx=30497
# Skipping SED simulation for idx=30498
# Skipping SED simulation for idx=30499
# Skipping SED simulation for idx=30500
# Skipping SED simulation for idx=30501
# Skipping SED simulation for idx=30502
# Skipping SED simulation for idx=30503
# Skipping SED simulation for idx=30504
# Skipping SED simulation for idx=30505
# Skipping SED simulation for idx=30506
# Skipping SED simulation for idx=30507
# Skipping SED simulation for idx=30508
# Skipping SED simulation for idx=30509
# Skipping SED simulation for idx=30510
# Skipping SED simulation for idx=30511
# Skipping SED simulation for idx=30512
# Skipping SED simulation for idx=30513
# Skipping SED simulation for idx=30514
# Skipping SED simulation for idx=30515
# Skipping SED simulation for idx=30516
# Skipping SED simulation for idx=30517
# Skipping SED simulation for idx=30518
# Skipping SED simulation for idx=30519
# Skipping SED simulation for idx=30520
# Skipping SED simulation for idx=30521
# Skipping SED simulation for idx=30522
# Skipping SED simulation for idx=30523
# Skipping SED simulation for idx=30524
# Skipping SED simulation for idx=30525
# Skipping SED simulation for idx=30526
# Skipping SED simulation for idx=30527
# Skipping SED simulation for idx=30528
# Skipping SED simulation for idx=30529
# Skipping SED simulation for idx=30530
# Skipping SED simulation for idx=30531
# Skipping SED simulation for idx=30532
# Skipping SED simulation for idx=30533
# Skipping SED simulation for idx=30534
# Skipping SED simulation for idx=30535
# Skipping SED simulation for idx=30536
# Skipping SED simulation for idx=30537
# Skipping SED simulation for idx=30538
# Skipping SED simulation for idx=30539
# Skipping SED simulation for idx=30540
# Skipping SED simulation for idx=30541
# Skipping SED simulation for idx=30542
# Skipping SED simulation for idx=30543
# Skipping SED simulation for idx=30544
# Skipping SED simulation for idx=30545
# Skipping SED simulation for idx=30546
# Skipping SED simulation for idx=30547
# Skipping SED simulation for idx=30548
# Skipping SED simulation for idx=30549
# Skipping SED simulation for idx=30550
# Skipping SED simulation for idx=30551
# Skipping SED simulation for idx=30552
# Skipping SED simulation for idx=30553
# Skipping SED simulation for idx=30554
# Skipping SED simulation for idx=30555
# Skipping SED simulation for idx=30556
# Skipping SED simulation for idx=30557
# Skipping SED simulation for idx=30558
# Skipping SED simulation for idx=30559
# Skipping SED simulation for idx=30560
# Skipping SED simulation for idx=30561
# Skipping SED simulation for idx=30562
# Skipping SED simulation for idx=30563
# Skipping SED simulation for idx=30564
# Skipping SED simulation for idx=30565
# Skipping SED simulation for idx=30566
# Skipping SED simulation for idx=30567
# Skipping SED simulation for idx=30568
# Skipping SED simulation for idx=30569
# Skipping SED simulation for idx=30570
# Skipping SED simulation for idx=30571
# Skipping SED simulation for idx=30572
# Skipping SED simulation for idx=30573
# Skipping SED simulation for idx=30574
# Skipping SED simulation for idx=30575
# Skipping SED simulation for idx=30576
# Skipping SED simulation for idx=30577
# Skipping SED simulation for idx=30578
# Skipping SED simulation for idx=30579
# Skipping SED simulation for idx=30580
# Skipping SED simulation for idx=30581
# Skipping SED simulation for idx=30582
# Skipping SED simulation for idx=30583
# Skipping SED simulation for idx=30584
# Skipping SED simulation for idx=30585
# Skipping SED simulation for idx=30586
# Skipping SED simulation for idx=30587
# Skipping SED simulation for idx=30588
# Skipping SED simulation for idx=30589
# Skipping SED simulation for idx=30590
# Skipping SED simulation for idx=30591
# Skipping SED simulation for idx=30592
# Skipping SED simulation for idx=30593
# Skipping SED simulation for idx=30594
# Skipping SED simulation for idx=30595
# Skipping SED simulation for idx=30596
# Skipping SED simulation for idx=30597
# Skipping SED simulation for idx=30598
# Skipping SED simulation for idx=30599
# Skipping SED simulation for idx=30600
# Skipping SED simulation for idx=30601
# Skipping SED simulation for idx=30602
# Skipping SED simulation for idx=30603
# Skipping SED simulation for idx=30604
# Skipping SED simulation for idx=30605
# Skipping SED simulation for idx=30606
# Skipping SED simulation for idx=30607
# Skipping SED simulation for idx=30608
# Skipping SED simulation for idx=30609
# Skipping SED simulation for idx=30610
# Skipping SED simulation for idx=30611
# Skipping SED simulation for idx=30612
# Skipping SED simulation for idx=30613
# Skipping SED simulation for idx=30614
# Skipping SED simulation for idx=30615
# Skipping SED simulation for idx=30616
# Skipping SED simulation for idx=30617
# Skipping SED simulation for idx=30618
# Skipping SED simulation for idx=30619
# Skipping SED simulation for idx=30620
# Skipping SED simulation for idx=30621
# Skipping SED simulation for idx=30622
# Skipping SED simulation for idx=30623
# Skipping SED simulation for idx=30624
# Skipping SED simulation for idx=30625
# Skipping SED simulation for idx=30626
# Skipping SED simulation for idx=30627
# Skipping SED simulation for idx=30628
# Skipping SED simulation for idx=30629
# Skipping SED simulation for idx=30630
# Skipping SED simulation for idx=30631
# Skipping SED simulation for idx=30632
# Skipping SED simulation for idx=30633
# Skipping SED simulation for idx=30634
# Skipping SED simulation for idx=30635
# Skipping SED simulation for idx=30636
# Skipping SED simulation for idx=30637
# Skipping SED simulation for idx=30638
# Skipping SED simulation for idx=30639
# Skipping SED simulation for idx=30640
# Skipping SED simulation for idx=30641
# Skipping SED simulation for idx=30642
# Skipping SED simulation for idx=30643
# Skipping SED simulation for idx=30644
# Skipping SED simulation for idx=30645
# Skipping SED simulation for idx=30646
# Skipping SED simulation for idx=30647
# Skipping SED simulation for idx=30648
# Skipping SED simulation for idx=30649
# Skipping SED simulation for idx=30650
# Skipping SED simulation for idx=30651
# Skipping SED simulation for idx=30652
# Skipping SED simulation for idx=30653
# Skipping SED simulation for idx=30654
# Skipping SED simulation for idx=30655
# Skipping SED simulation for idx=30656
# Skipping SED simulation for idx=30657
# Skipping SED simulation for idx=30658
# Skipping SED simulation for idx=30659
# Skipping SED simulation for idx=30660
# Skipping SED simulation for idx=30661
# Skipping SED simulation for idx=30662
# Skipping SED simulation for idx=30663
# Skipping SED simulation for idx=30664
# Skipping SED simulation for idx=30665
# Skipping SED simulation for idx=30666
# Skipping SED simulation for idx=30667
# Skipping SED simulation for idx=30668
# Skipping SED simulation for idx=30669
# Skipping SED simulation for idx=30670
# Skipping SED simulation for idx=30671
# Skipping SED simulation for idx=30672
# Skipping SED simulation for idx=30673
# Skipping SED simulation for idx=30674
# Skipping SED simulation for idx=30675
# Skipping SED simulation for idx=30676
# Skipping SED simulation for idx=30677
# Skipping SED simulation for idx=30678
# Skipping SED simulation for idx=30679
# Skipping SED simulation for idx=30680
# Skipping SED simulation for idx=30681
# Skipping SED simulation for idx=30682
# Skipping SED simulation for idx=30683
# Skipping SED simulation for idx=30684
# Skipping SED simulation for idx=30685
# Skipping SED simulation for idx=30686
# Skipping SED simulation for idx=30687
# Skipping SED simulation for idx=30688
# Skipping SED simulation for idx=30689
# Skipping SED simulation for idx=30690
# Skipping SED simulation for idx=30691
# Skipping SED simulation for idx=30692
# Skipping SED simulation for idx=30693
# Skipping SED simulation for idx=30694
# Skipping SED simulation for idx=30695
# Skipping SED simulation for idx=30696
# Skipping SED simulation for idx=30697
# Skipping SED simulation for idx=30698
# Skipping SED simulation for idx=30699
# Skipping SED simulation for idx=30700
# Skipping SED simulation for idx=30701
# Skipping SED simulation for idx=30702
# Skipping SED simulation for idx=30703
# Skipping SED simulation for idx=30704
# Skipping SED simulation for idx=30705
# Skipping SED simulation for idx=30706
# Skipping SED simulation for idx=30707
# Skipping SED simulation for idx=30708
# Skipping SED simulation for idx=30709
# Skipping SED simulation for idx=30710
# Skipping SED simulation for idx=30711
# Skipping SED simulation for idx=30712
# Skipping SED simulation for idx=30713
# Skipping SED simulation for idx=30714
# Skipping SED simulation for idx=30715
# Skipping SED simulation for idx=30716
# Skipping SED simulation for idx=30717
# Skipping SED simulation for idx=30718
# Skipping SED simulation for idx=30719
# Skipping SED simulation for idx=30720
# Skipping SED simulation for idx=30721
# Skipping SED simulation for idx=30722
# Skipping SED simulation for idx=30723
# Skipping SED simulation for idx=30724
# Skipping SED simulation for idx=30725
# Skipping SED simulation for idx=30726
# Skipping SED simulation for idx=30727
# Skipping SED simulation for idx=30728
# Skipping SED simulation for idx=30729
# Skipping SED simulation for idx=30730
# Skipping SED simulation for idx=30731
# Skipping SED simulation for idx=30732
# Skipping SED simulation for idx=30733
# Skipping SED simulation for idx=30734
# Skipping SED simulation for idx=30735
# Skipping SED simulation for idx=30736
# Skipping SED simulation for idx=30737
# Skipping SED simulation for idx=30738
# Skipping SED simulation for idx=30739
# Skipping SED simulation for idx=30740
# Skipping SED simulation for idx=30741
# Skipping SED simulation for idx=30742
# Skipping SED simulation for idx=30743
# Skipping SED simulation for idx=30744
# Skipping SED simulation for idx=30745
# Skipping SED simulation for idx=30746
# Skipping SED simulation for idx=30747
# Skipping SED simulation for idx=30748
# Skipping SED simulation for idx=30749
# Skipping SED simulation for idx=30750
# Skipping SED simulation for idx=30751
# Skipping SED simulation for idx=30752
# Skipping SED simulation for idx=30753
# Skipping SED simulation for idx=30754
# Skipping SED simulation for idx=30755
# Skipping SED simulation for idx=30756
# Skipping SED simulation for idx=30757
# Skipping SED simulation for idx=30758
# Skipping SED simulation for idx=30759
# Skipping SED simulation for idx=30760
# Skipping SED simulation for idx=30761
# Skipping SED simulation for idx=30762
# Skipping SED simulation for idx=30763
# Skipping SED simulation for idx=30764
# Skipping SED simulation for idx=30765
# Skipping SED simulation for idx=30766
# Skipping SED simulation for idx=30767
# Skipping SED simulation for idx=30768
# Skipping SED simulation for idx=30769
# Skipping SED simulation for idx=30770
# Skipping SED simulation for idx=30771
# Skipping SED simulation for idx=30772
# Skipping SED simulation for idx=30773
# Skipping SED simulation for idx=30774
# Skipping SED simulation for idx=30775
# Skipping SED simulation for idx=30776
# Skipping SED simulation for idx=30777
# Skipping SED simulation for idx=30778
# Skipping SED simulation for idx=30779
# Skipping SED simulation for idx=30780
# Skipping SED simulation for idx=30781
# Skipping SED simulation for idx=30782
# Skipping SED simulation for idx=30783
# Skipping SED simulation for idx=30784
# Skipping SED simulation for idx=30785
# Skipping SED simulation for idx=30786
# Skipping SED simulation for idx=30787
# Skipping SED simulation for idx=30788
# Skipping SED simulation for idx=30789
# Skipping SED simulation for idx=30790
# Skipping SED simulation for idx=30791
# Skipping SED simulation for idx=30792
# Skipping SED simulation for idx=30793
# Skipping SED simulation for idx=30794
# Skipping SED simulation for idx=30795
# Skipping SED simulation for idx=30796
# Skipping SED simulation for idx=30797
# Skipping SED simulation for idx=30798
# Skipping SED simulation for idx=30799
# Skipping SED simulation for idx=30800
# Skipping SED simulation for idx=30801
# Skipping SED simulation for idx=30802
# Skipping SED simulation for idx=30803
# Skipping SED simulation for idx=30804
# Skipping SED simulation for idx=30805
# Skipping SED simulation for idx=30806
# Skipping SED simulation for idx=30807
# Skipping SED simulation for idx=30808
# Skipping SED simulation for idx=30809
# Skipping SED simulation for idx=30810
# Skipping SED simulation for idx=30811

# %%
sim1.write_catalog('wfirst_snhostspec2.dat')
# Out:
# Wrote sim data catalog to wfirst_snhostspec2.dat
