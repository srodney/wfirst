# %%
# %matplotlib inline

# %%
import numpy as np
from astropy.io import fits
from astropy.table import Table
from matplotlib import pyplot as plt
import snhostspec
from glob import glob

# %%
reload(snhostspec)
sim = snhostspec.SnanaSimData()
sim.load_simdata_catalog('/Users/rodney/Dropbox/src/wfirst/wfirst_snhostspec3.cat')
sim.plot_efficiency_curves(dz=0.2, verbose=True)
print(len(sim.simdata))
# Out:
# Initiliazed an empty WfirstSimData object
# #et   0.8   1.0   1.2   1.4   1.6   1.8   2.0   2.2
# 40hr 0.99  0.95  0.93  0.86  0.73  0.52  0.57  0.38
# 10hr 0.96  0.88  0.87  0.68  0.51  0.28  0.24  0.25
# 5hr  0.93  0.84  0.75  0.53  0.35  0.20  0.14  0.12
# 1hr  0.78  0.46  0.27  0.15  0.07  0.00  0.00  0.00
# 751

# %%
i=33
etcoutfile = 'etc.output/subaruPFS_SNR.40hr.000{:03d}.dat'.format(i)
subarusim = snhostspec.SubaruObsSim(etcoutfile, 1, 25, 40)
subarusim.check_redshift(snrthresh=4, showplot=False)
subarusim.plot(showspec=True)
# Out:
# Redshift detected. Max S/N=9.8 at rest wave=409 nm

# %%
ef = [0.27, 0.75, 0.87, 0.93]
et = [1, 5, 10, 40]

# %%
np.interp.interp1d(et, ef)(16)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-a4f8b3ee7d8d> in <module>()
# ----> 1 np.interp.interp1d(et, ef)(16)
#
# AttributeError: 'function' object has no attribute 'interp1d'

# %%
from scipy import interpolate

# %%
interp = interpolate.interp1d(et, ef)

# %%
print( interp(16))
# Out:
# 0.882

# %%
plot(et, ef, 'ko')
